# %% [markdown]
# # Tarea del Sprint 2
#
# pruebo _itálicas_ y *otras itálicas*, también **negritas**

# %% [markdown]
# Pero si quiero imprimir entre asteriscos: \*entre asteriscos\*

# %% [markdown]
# ## Cálculos matemáticos

# %% [markdown]
# * suma y resta
#     * nros fijos
#     * variables
#     * ingreso por teclado
# * multiplicación y división
# * potencia y módulo

# %% [markdown]
# ### Suma y resta

# %%
# suma y resta
print('Valores fijos: ', 10 + 45 + 12 - 5)

a = 4
b = 10
c = 12
print('Con variables: ', a + b - c)

x = int(input('Ingresa un entero: '))
y = int(input('Ingresa otro entero para sumarlo: '))      
print('Resultado: ',x + y)
# Out:
# Valores fijos:  62
# Con variables:  2
# Ingresa un entero: 5
# Ingresa otro entero para sumarlo: 78
# Resultado:  83

# %% [markdown]
# ### Multiplicación y división
# ******
# ~~Esto mejor lo dejo tachado~~

# %%
# multiplicación de nros fijos
print('Multiplicación :', 25 * 5)

# división (da un float)
print('División: ', 81 / 9)
# Out:
# Multiplicación : 125
# División:  9.0

# %% [markdown]
# ### Potencia y módulo
# La **división** da un _float_ y el **módulo** da un _entero_

# %%
# potencia
print('Potencia: ', 5 ** 3)

# módulo (da un int)
print('Módulo: ', 81 // 9)
# Out:
# Potencia:  125
# Módulo:  9

# %% [markdown]
# ## Imágenes en el notebook
# > ahora inserto imágenes
# > para que se vean en el final

# %% [markdown]
# ### Lista de imágenes
# + paisajes:
#     1. mar
#     2. montaña
# + ciudades:
#     1. edificios

# %% [markdown]
# ![mar.jpg](attachment:mar.jpg)
# ![monta%C3%B1a.jpg](attachment:monta%C3%B1a.jpg)
# ![ciudad.jpg](attachment:ciudad.jpg)
